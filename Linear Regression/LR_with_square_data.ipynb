# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
data = pd.read_csv('data_square.csv').values
N = data.shape[0]
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)
plt.scatter(x, y)
plt.xlabel('mét vuông')
plt.ylabel('giá')
# Out:
# Text(0, 0.5, 'giá')

# %%
data = pd.read_csv('data_square.csv').values
N = data.shape[0]
x = data[:, 0].reshape(-1, 1)
y = data[:, 1].reshape(-1, 1)
plt.scatter(x, y)
plt.xlabel('mét vuông')
plt.ylabel('giá')
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)
plt.plot((x[0], x[-1]), (y_pred[0], y_pred[-1]), 'g')
plt.show()
np.savez('w3.npz', a=model.intercept_, b=model.coef_)

k = np.load('w3.npz')
model.intercept_ = k['a']
model.coef_ = k['b']

# %%
print(x)
# Out:
# [[  1.      30.    ]
#  [  1.      32.4138]
#  [  1.      34.8276]
#  [  1.      37.2414]
#  [  1.      39.6552]
#  [  1.      42.069 ]
#  [  1.      44.4828]
#  [  1.      46.8966]
#  [  1.      49.3103]
#  [  1.      51.7241]
#  [  1.      54.1379]
#  [  1.      56.5517]
#  [  1.      58.9655]
#  [  1.      61.3793]
#  [  1.      63.7931]
#  [  1.      66.2069]
#  [  1.      68.6207]
#  [  1.      71.0345]
#  [  1.      73.4483]
#  [  1.      75.8621]
#  [  1.      78.2759]
#  [  1.      80.6897]
#  [  1.      83.1034]
#  [  1.      85.5172]
#  [  1.      87.931 ]
#  [  1.      90.3448]
#  [  1.      92.7586]
#  [  1.      95.1724]
#  [  1.      97.5862]
#  [  1.     100.    ]]
